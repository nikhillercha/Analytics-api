# %%
print("hello world")
# Out:
# hello world

# %%
import requests
import httpx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import requests
#       2 import httpx
#
# ModuleNotFoundError: No module named 'requests'

# %%
# pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.9-cp314-cp314-macosx_10_15_universal2.whl.metadata (41 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikhillercha/CODE/Projects/Analytics-api/venv/lib/python3.14/site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/nikhillercha/CODE/Projects/Analytics-api/venv/lib/python3.14/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/nikhillercha/CODE/Projects/Analytics-api/venv/lib/python3.14/site-packages (from requests) (2026.6.17)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.9-cp314-cp314-macosx_10_15_universal2.whl (317 kB)
# Installing collected packages: charset_normalizer, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [requests]
# Successfully installed charset_normalizer-3.4.9 requests-2.34.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
path = "/healthz"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
